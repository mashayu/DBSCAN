# %%
np.shape(lines)
# Out:
# (301, 301)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("C:/Users/masha/Documents/TU/DBSCAN/DBSCAN/example.txt") as textFile:
    lines = [line.split() for line in textFile]
np.shape(lines)
d = [[float(y) for y in x] for x in lines]
a = np.array(d)
np.shape(a)
# Out:
# (301, 301)

# %%
tr = np.ma.masked_where(a > 0, a)

cmap1 = plt.cm.binary
cmap1.set_bad(color='black')

# %%
fig, ax = plt.subplots(figsize=(18, 18))
e = ax.imshow(tr[:40,50:250],  cmap = "binary")

# %%
import csv

with open('polar_1cycle.csv') as f:
    reader = csv.reader(f, delimiter='\t')
    data = [(col1)
                for col1 in reader]
data
# Out:
# [['1 4.16641 -4.57451 18 28'],
#  ['1 14.3726 10.6275 8 18'],
#  ['1 3.68567 -2.89629 18 28'],
#  ['1 2.43372 -1.80707 45 57'],
#  ['1 14.0573 -7.60876 17 27'],
#  ['1 0 0 35 42'],
#  ['1 9.75303 -0.495902 16 28'],
#  ['1 12.227 -3.55866 23 33'],
#  ['1 9.19329 -2.06279 16 27'],
#  ['1 7.10218 -3.57928 22 34'],
#  ['1 16.4171 -2.71822 16 26'],
#  ['1 10.9572 -2.68438 21 31'],
#  ['1 5.75077 -6.69809 15 25'],
#  ['1 7.06923 -1.29852 19 30'],
#  ['1 13.5969 14.0212 13 25'],
#  ['1 1.7798 -1.10277 63 76'],
#  ['1 17.4565 -10.6283 35 45'],
#  ['1 14.4957 -10.9845 9 18'],
#  ['1 3.01315 -2.67804 25 36'],
#  ['1 4.77358 -2.1091 21 33'],
#  ['1 17.2052 -8.17102 10 19'],
#  ['1 19.6449 8.22397 18 28'],
#  ['1 11.4992 -8.46886 20 30'],
#  ['1 8.84012 -5.6948 23 34'],
#  ['1 14.4541 4.7633 11 21'],
#  ['1 21.2275 -7.64594 9 19'],
#  ['2 -0.0114098 -23.5781 18 27'],
#  ['2 9.13956 -6.26046 20 30'],
#  ['2 13.8114 8.65061 19 29'],
#  ['2 12.7046 18.6834 18 27'],
#  ['2 14.3947 -3.93111 27 36'],
# ...

# %%
# Out:
# (216880,)

# %%
import numpy as np
import matplotlib.pyplot as plt


# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
#N = 150
#r = 2 * np.random.rand(N)
#theta = 2 * np.pi * np.random.rand(N)
#area = 200 * r**2
colors = amp

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='polar')
pol = ax.scatter(theta, r, c=amp, cmap='jet', alpha=0.75)
fig.colorbar(pol)

plt.show()

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

theta = 2 * np.pi * np.random.random(1000)
r = 6 * np.random.random(1000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = f(x, y)


ax = plt.axes(projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d


r = np.loadtxt('coord.txt', usecols = 0)
theta = np.loadtxt('coord.txt', usecols = 1)
phi = np.loadtxt('coord.txt', usecols = 2)

theta = theta[:150]
phi = phi[:150]
#theta, phi = np.linspace(0, 2 * np.pi, 40), np.linspace(0, np.pi, 40)
THETA, PHI = np.meshgrid(theta, phi)
#R = np.cos(PHI**2)
R = r[:150]

#print(phi)
#print(R)
X = R * np.sin(phi) * np.cos(theta)
Y = R * np.sin(phi) * np.sin(theta)
Z = R * np.cos(phi)
#print(np.shape(Z))
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(X, Y, Z, c = Z, cmap='viridis', linewidth=0.5)
#plot = ax.plot_surface(
 #   X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('jet'),
  #  linewidth=0, antialiased=False, alpha=0.5)
print(X)
print(Y)
print(Z)
plt.show()
# Out:
# [-5.67207432e-01  4.82516037e+00  8.68269925e-01  5.53861065e-01
#  -3.31061330e+00  0.00000000e+00 -4.08171354e+00 -4.52836396e+00
#   3.82768055e+00 -2.72646875e+00  6.14925782e+00  4.34021274e+00
#  -2.12146686e+00 -1.83105605e+00  1.56269207e+00 -7.16568586e-01
#  -5.85012882e+00 -1.60516426e-01  1.20508831e+00  2.10121936e+00
#   5.09647243e+00 -6.62299052e+00  5.41846596e+00  4.08135540e+00
#  -7.34602073e-01 -4.28987619e+00 -1.84294368e-04  2.07627806e-01
#  -6.90395821e+00 -2.07230614e+00 -7.19710576e+00 -9.23327108e-01
#  -1.59504260e+00 -3.73997964e+00  2.55838975e-01 -1.46246160e+00
#   1.59574062e+00  3.81427239e+00  1.83750644e+00  6.19022669e-02
#   2.47527501e+00  8.77475950e-01 -8.33283724e+00 -1.14206776e+00
#  -1.16324513e+00 -2.08754027e+00 -5.71295245e+00 -3.17868404e+00
#   2.60957318e+00 -5.84721782e+00  4.29435879e+00 -7.73595773e-03
#   1.99021072e+00 -2.55948768e-01 -8.67055051e+00 -4.80212468e+00
# ...

# %%
plt.scatter(X,Y, c = Z)
